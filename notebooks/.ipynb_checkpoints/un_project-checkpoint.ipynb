# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
#read _method
gdp_df=pd.read_csv('../data/gdp_percapita.csv')

# %%
gdp_df
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2020  1970.560169              NaN
# 1        Afghanistan  2019  2065.036235              NaN
# 2        Afghanistan  2018  2033.804389              NaN
# 3        Afghanistan  2017  2058.400221              NaN
# 4        Afghanistan  2016  2057.067978              NaN
# ...              ...   ...          ...              ...
# 7171        Zimbabwe  1994  2603.927369              NaN
# 7172        Zimbabwe  1993  2420.092791              NaN
# 7173        Zimbabwe  1992  2437.152908              NaN
# 7174        Zimbabwe  1991  2733.696626              NaN
# 7175        Zimbabwe  1990  2652.129209              NaN
#
# [7176 rows x 4 columns]

# %% [markdown]
# ANS.many rows and columns =7176 rows × 4 columns

# %%
type(gdp_df)
# Out:
# pandas.core.frame.DataFrame

# %%
print(type(gdp_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data_types=gdp_df

# %%
#dtatype
gdp_df.dtypes
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %%
gdp_df.dtypes
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %%
# Drop the column
gdp_df=gdp_df.drop(columns=['Value Footnotes'])

# %%
gdp_df
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2020  1970.560169
# 1        Afghanistan  2019  2065.036235
# 2        Afghanistan  2018  2033.804389
# 3        Afghanistan  2017  2058.400221
# 4        Afghanistan  2016  2057.067978
# ...              ...   ...          ...
# 7171        Zimbabwe  1994  2603.927369
# 7172        Zimbabwe  1993  2420.092791
# 7173        Zimbabwe  1992  2437.152908
# 7174        Zimbabwe  1991  2733.696626
# 7175        Zimbabwe  1990  2652.129209
#
# [7176 rows x 3 columns]

# %%
#change column name
gdp_df = gdp_df.rename(columns={'Country or Area': 'Country', 'Year': 'Year', 'Value': 'GDP_Per_Capita'})

# %%
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2020     1970.560169
# 1     Afghanistan  2019     2065.036235
# 2     Afghanistan  2018     2033.804389
# 3     Afghanistan  2017     2058.400221
# 4     Afghanistan  2016     2057.067978
# ...           ...   ...             ...
# 7171     Zimbabwe  1994     2603.927369
# 7172     Zimbabwe  1993     2420.092791
# 7173     Zimbabwe  1992     2437.152908
# 7174     Zimbabwe  1991     2733.696626
# 7175     Zimbabwe  1990     2652.129209
#
# [7176 rows x 3 columns]

# %%
#many countries total 
gdp_df.Country.value_counts().to_frame()
# Out:
#                                               count
# Country
# Least developed countries: UN classification     31
# Niger                                            31
# Middle East & North Africa (IDA & IBRD)          31
# Middle income                                    31
# Mongolia                                         31
# ...                                             ...
# Kosovo                                           13
# Turks and Caicos Islands                         10
# Sint Maarten (Dutch part)                        10
# Somalia                                           8
# Djibouti                                          8
#
# [242 rows x 1 columns]

# %%
gdp_df.Country.value_counts().to_frame().reset_index()
# Out:
#                                           Country  count
# 0    Least developed countries: UN classification     31
# 1                                           Niger     31
# 2         Middle East & North Africa (IDA & IBRD)     31
# 3                                   Middle income     31
# 4                                        Mongolia     31
# ..                                            ...    ...
# 237                                        Kosovo     13
# 238                      Turks and Caicos Islands     10
# 239                     Sint Maarten (Dutch part)     10
# 240                                       Somalia      8
# 241                                      Djibouti      8
#
# [242 rows x 2 columns]

# %%
country_count=gdp_df.Country.value_counts().to_frame().reset_index()

# %%
country_count
# Out:
#                                           Country  count
# 0    Least developed countries: UN classification     31
# 1                                           Niger     31
# 2         Middle East & North Africa (IDA & IBRD)     31
# 3                                   Middle income     31
# 4                                        Mongolia     31
# ..                                            ...    ...
# 237                                        Kosovo     13
# 238                      Turks and Caicos Islands     10
# 239                     Sint Maarten (Dutch part)     10
# 240                                       Somalia      8
# 241                                      Djibouti      8
#
# [242 rows x 2 columns]

# %%
#count the country
country_count.query('count==31')
# Out:
#                                           Country  count
# 0    Least developed countries: UN classification     31
# 1                                           Niger     31
# 2         Middle East & North Africa (IDA & IBRD)     31
# 3                                   Middle income     31
# 4                                        Mongolia     31
# ..                                            ...    ...
# 200                                      IDA only     31
# 201      Fragile and conflict affected situations     31
# 202                                       Ireland     31
# 203                                        France     31
# 204                                         Italy     31
#
# [205 rows x 2 columns]

# %%
#missing the data but counting 
missing_count=country_count.query('count!=31')
missing_count
# Out:
#                        Country  count
# 205               Turkmenistan     30
# 206                    Hungary     30
# 207            Slovak Republic     29
# 208                   Cambodia     28
# 209         West Bank and Gaza     27
# 210     Bosnia and Herzegovina     27
# 211                   Slovenia     26
# 212                     Latvia     26
# 213                     Israel     26
# 214                  Lithuania     26
# 215                     Serbia     26
# 216                    Moldova     26
# 217                    Iceland     26
# 218                    Croatia     26
# 219                    Estonia     26
# 220                     Kuwait     26
# 221                   Maldives     26
# 222                     Canada     24
# 223                 Montenegro     24
# 224               Small states     24
# 225                 San Marino     24
# 226                      Libya     22
# 227         Other small states     21
# 228                    Liberia     21
# ...

# %%
missing_count.shape
# Out:
# (37, 2)

# %% [markdown]
# #plots to show the distribution of GDP per capita for the year 2020

# %% [markdown]
# #histogram plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Filter the data for the year 2020

# %%
gdp_df[gdp_df['Year'] == 2020]
# Out:
#                           Country  Year  GDP_Per_Capita
# 0                     Afghanistan  2020     1970.560169
# 19    Africa Eastern and Southern  2020     3491.978104
# 50     Africa Western and Central  2020     4021.293919
# 81                        Albania  2020    13253.733337
# 112                       Algeria  2020    10735.382539
# ...                           ...   ...             ...
# 7025                      Vietnam  2020    10338.270543
# 7056           West Bank and Gaza  2020     5402.538773
# 7083                        World  2020    16269.969854
# 7114                       Zambia  2020     3277.816510
# 7145                     Zimbabwe  2020     2134.555461
#
# [240 rows x 3 columns]

# %%
gdp_2020 = gdp_df[gdp_df['Year'] == 2020]

# %% [markdown]
# #histogram

# %%
plt.hist(gdp_2020['GDP_Per_Capita'], bins=40, color='skyblue')
plt.title('Distribution of GDP per Capita in 2020')
plt.xlabel('GDP per Capita')
plt.ylabel('No.of Countries')

plt.show()

# %% [markdown]
# # Density Graph

# %%
sns.kdeplot(gdp_2020['GDP_Per_Capita'], color='skyblue')
plt.title('Density Plot of GDP per Capita in 2020')
plt.xlabel('GDP per Capita')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# # Boxplot graph

# %%
sns.boxplot(gdp_2020, y='GDP_Per_Capita', color='skyblue')
plt.title('Boxplot of GDP per Capita in 2020')
plt.ylabel('GDP per Capita')

plt.show()

# %% [markdown]
# # violin plot graph

# %%
sns.violinplot(data=gdp_2020, y='GDP_Per_Capita' )
plt.title('Violin Plot of GDP per Capita in 2020')
plt.ylabel('GDP per Capita')

plt.show()

# %%
violinplot_1 = sns.violinplot(x='GDP_Per_Capita', data =gdp_2020 )

# %% [markdown]
# #median GDP per capita for 2020

# %%
gdp_2020['GDP_Per_Capita'].median()
# Out:
# 12908.9374056206

# %%
median_gdp_2020=gdp_2020['GDP_Per_Capita'].median()

# %%
# compare GDP per capita values for the years 1990, 2000, 2010, and 2020

# %%
years_to_select = [1990, 2000, 2010, 2020] 
gdp_df[gdp_df['Year'].isin(years_to_select)]
gdp_decades = gdp_df[gdp_df['Year'].isin(years_to_select)]
gdp_decades
# Out:
#                           Country  Year  GDP_Per_Capita
# 0                     Afghanistan  2020     1970.560169
# 10                    Afghanistan  2010     1957.029070
# 19    Africa Eastern and Southern  2020     3491.978104
# 29    Africa Eastern and Southern  2010     3545.205203
# 39    Africa Eastern and Southern  2000     2915.472987
# ...                           ...   ...             ...
# 7144                       Zambia  1990     2190.181724
# 7145                     Zimbabwe  2020     2134.555461
# 7155                     Zimbabwe  2010     1813.531764
# 7165                     Zimbabwe  2000     2771.060576
# 7175                     Zimbabwe  1990     2652.129209
#
# [918 rows x 3 columns]

# %% [markdown]
# # boxplot for GDP per capita over the selected decades

# %%
sns.boxplot(gdp_decades, x='Year', y='GDP_Per_Capita', color='skyblue')
plt.title('Boxplot of GDP per Capita (1990, 2000, 2010, 2020)')
plt.xlabel('Year')
plt.ylabel('GDP per Capita')

plt.show()

# %%
sns.barplot(gdp_decades, x='Year', y='GDP_Per_Capita', color='skyblue')
plt.title('Barplot of GDP per Capita (1990, 2000, 2010, 2020)')
plt.xlabel('Year')
plt.ylabel('GDP per Capita')

plt.show()

# %% [markdown]
# # scatterplot

# %%
sns.scatterplot(data=gdp_decades, x='Year', y='GDP_Per_Capita', hue='Country', palette='viridis')
plt.title('Scatterplot of GDP per Capita (1990, 2000, 2010, 2020)')
plt.xlabel('Year')
plt.ylabel('GDP per Capita')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
#Comment on what you observe has happened to GDP values over time 
#and the relative strengths and weaknesses of each type of plot.

# %%
# 11. Filter!!GDP per capita greater than $100,000
high_income_countries=gdp_df[gdp_df['GDP_Per_Capita']>100000]
high_income_countries
# Out:
#                    Country  Year  GDP_Per_Capita
# 3882            Luxembourg  2020   112557.309472
# 3883            Luxembourg  2019   116518.276815
# 3884            Luxembourg  2018   115049.926079
# 3885            Luxembourg  2017   114985.842236
# 3886            Luxembourg  2016   116283.699681
# 3887            Luxembourg  2015   113182.728563
# 3888            Luxembourg  2014   113313.578898
# 3889            Luxembourg  2013   113050.663254
# 3890            Luxembourg  2012   112137.135491
# 3891            Luxembourg  2011   112998.390477
# 3892            Luxembourg  2010   114343.988089
# 3893            Luxembourg  2009   112230.081410
# 3894            Luxembourg  2008   118154.667184
# 3895            Luxembourg  2007   120647.822959
# 3896            Luxembourg  2006   113346.035782
# 3897            Luxembourg  2005   108632.360016
# 3898            Luxembourg  2004   107634.837198
# 3899            Luxembourg  2003   104743.000088
# ...

# %%
# Sort the DataFrame by year and GDP_Per_Capita in ascending order
high_income_countries = high_income_countries.sort_values(by=['Year', 'GDP_Per_Capita'], ascending=[True, True])
high_income_countries
# Out:
#                    Country  Year  GDP_Per_Capita
# 6838  United Arab Emirates  1990   111454.055665
# 6837  United Arab Emirates  1991   106103.552655
# 6836  United Arab Emirates  1992   103470.924576
# 6834  United Arab Emirates  1994   100213.156226
# 6833  United Arab Emirates  1995   101570.992100
# 6832  United Arab Emirates  1996   102211.638844
# 6831  United Arab Emirates  1997   105108.996265
# 6830  United Arab Emirates  1998   100100.435658
# 6828  United Arab Emirates  2000   102494.714624
# 3901            Luxembourg  2001   101143.147977
# 3900            Luxembourg  2002   103317.331098
# 3899            Luxembourg  2003   104743.000088
# 3898            Luxembourg  2004   107634.837198
# 3897            Luxembourg  2005   108632.360016
# 3896            Luxembourg  2006   113346.035782
# 3895            Luxembourg  2007   120647.822959
# 3894            Luxembourg  2008   118154.667184
# 3893            Luxembourg  2009   112230.081410
# ...

# %%
 high_income_countries.iloc[0]
# Out:
# Country           United Arab Emirates
# Year                              1990
# GDP_Per_Capita           111454.055665
# Name: 6838, dtype: object

# %%
#12. Filter the DataFrame for the year 2020
gdp_2020=gdp_df[gdp_df['Year']==2020]
gdp_2020
# Out:
#                           Country  Year  GDP_Per_Capita
# 0                     Afghanistan  2020     1970.560169
# 19    Africa Eastern and Southern  2020     3491.978104
# 50     Africa Western and Central  2020     4021.293919
# 81                        Albania  2020    13253.733337
# 112                       Algeria  2020    10735.382539
# ...                           ...   ...             ...
# 7025                      Vietnam  2020    10338.270543
# 7056           West Bank and Gaza  2020     5402.538773
# 7083                        World  2020    16269.969854
# 7114                       Zambia  2020     3277.816510
# 7145                     Zimbabwe  2020     2134.555461
#
# [240 rows x 3 columns]

# %%
#row with the highest GDP_Per_Capita in 2020
highest_gdp_2020=gdp_2020[gdp_2020['GDP_Per_Capita']==gdp_2020['GDP_Per_Capita'].max()]
highest_gdp_2020
# Out:
#          Country  Year  GDP_Per_Capita
# 3882  Luxembourg  2020   112557.309472

# %%
#line plot to show the change in GDP per capita over the years
import matplotlib.pyplot as plt
country_name =highest_gdp_2020['Country'].values[0]
country_data = gdp_df[gdp_df['Country'] == country_name]
plt.plot(country_data['Year'], country_data['GDP_Per_Capita'], marker='o', linestyle='-', color='r')
plt.title(f'Change in GDP per Capita for {country_name} (1990-2020)')
plt.xlabel('Year')
plt.ylabel('GDP per Capita')

plt.show()

# %%
#13.Which country had the lowest GDP per capita in 2020
gdp_2020=gdp_df[gdp_df['Year']==2020]
gdp_2020
# Out:
#                           Country  Year  GDP_Per_Capita
# 0                     Afghanistan  2020     1970.560169
# 19    Africa Eastern and Southern  2020     3491.978104
# 50     Africa Western and Central  2020     4021.293919
# 81                        Albania  2020    13253.733337
# 112                       Algeria  2020    10735.382539
# ...                           ...   ...             ...
# 7025                      Vietnam  2020    10338.270543
# 7056           West Bank and Gaza  2020     5402.538773
# 7083                        World  2020    16269.969854
# 7114                       Zambia  2020     3277.816510
# 7145                     Zimbabwe  2020     2134.555461
#
# [240 rows x 3 columns]

# %%
#13.row with thelowest GDP_Per_Capita in 2020
lowest_gdp_2020=gdp_2020[gdp_2020['GDP_Per_Capita']==gdp_2020['GDP_Per_Capita'].min()]
lowest_gdp_2020
# Out:
#      Country  Year  GDP_Per_Capita
# 914  Burundi  2020      731.064074

# %%
import matplotlib.pyplot as plt

country_name = lowest_gdp_2020['Country'].values[0]
country_data = gdp_df[gdp_df['Country'] == country_name]

plt.plot(country_data['Year'], country_data['GDP_Per_Capita'], marker='o', linestyle='-', color='r')
plt.title(f'Change in GDP per Capita for {country_name} (1990-2020)')
plt.xlabel('Year')
plt.ylabel('GDP per Capita')

plt.show()

# %%
#read _method!! dataset into a DataFrame named

internet_df=pd.read_csv('../data/internet_use.csv',nrows=4495)
internet_df
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 0        Afghanistan  2014  6.390000              NaN
# 1        Afghanistan  2013  5.900000              NaN
# 2        Afghanistan  2012  5.454545              NaN
# 3        Afghanistan  2011  5.000000              NaN
# 4        Afghanistan  2010  4.000000              NaN
# ...              ...   ...       ...              ...
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN
#
# [4495 rows x 4 columns]

# %%
# datatypes of the columns
internet_df.dtypes
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %%
#15 Drop the `Value Footnotes` column
internet_df=internet_df.drop(columns=['Value Footnotes'])

# %%
#change column name
internet_df =internet_df.rename(columns={'Country or Area': 'Country', 'Year': 'Year', 'Value': 'Internet_Users_Pct'})
internet_df
# Out:
#           Country  Year  Internet_Users_Pct
# 0     Afghanistan  2014            6.390000
# 1     Afghanistan  2013            5.900000
# 2     Afghanistan  2012            5.454545
# 3     Afghanistan  2011            5.000000
# 4     Afghanistan  2010            4.000000
# ...           ...   ...                 ...
# 4490     Zimbabwe  1997            0.033080
# 4491     Zimbabwe  1996            0.016790
# 4492     Zimbabwe  1995            0.007684
# 4493     Zimbabwe  1994            0.001739
# 4494     Zimbabwe  1990            0.000000
#
# [4495 rows x 3 columns]

# %%
internet_df.loc[internet_df['Internet_Users_Pct']>0]
# Out:
#           Country  Year  Internet_Users_Pct
# 0     Afghanistan  2014            6.390000
# 1     Afghanistan  2013            5.900000
# 2     Afghanistan  2012            5.454545
# 3     Afghanistan  2011            5.000000
# 4     Afghanistan  2010            4.000000
# ...           ...   ...                 ...
# 4489     Zimbabwe  1998            0.081648
# 4490     Zimbabwe  1997            0.033080
# 4491     Zimbabwe  1996            0.016790
# 4492     Zimbabwe  1995            0.007684
# 4493     Zimbabwe  1994            0.001739
#
# [4106 rows x 3 columns]

# %%
internet_df.loc[internet_df['Internet_Users_Pct']>0]['Year'].min()
# Out:
# 1990

# %%
# How does the distribution of internet users percent differ for 2000 and 2014?
internet_2000_and_2014 = internet_df.loc[(internet_df['Year'] == 2000) | (internet_df['Year'] == 2014)]
internet_2000_and_2014
# Out:
#           Country  Year  Internet_Users_Pct
# 0     Afghanistan  2014            6.390000
# 15        Albania  2014           60.100000
# 29        Albania  2000            0.114097
# 36        Algeria  2014           18.090000
# 50        Algeria  2000            0.491706
# ...           ...   ...                 ...
# 4445        Yemen  2000            0.082500
# 4451       Zambia  2014           17.340000
# 4465       Zambia  2000            0.191072
# 4473     Zimbabwe  2014           19.890000
# 4487     Zimbabwe  2000            0.401434
#
# [401 rows x 3 columns]

# %%
# Create a histogram for the internet users percent in 2000
sns.histplot(internet_2000_and_2014[internet_2000_and_2014['Year'] == 2000]['Internet_Users_Pct'], bins=20, kde=True)
plt.title('Internet Users Percent Distribution (2000)')

plt.show()

# %%
# Create a histogram for the internet users percent in 2014

sns.histplot(internet_2000_and_2014[internet_2000_and_2014['Year'] == 2014]['Internet_Users_Pct'], bins=20, kde=True)
plt.title('Internet Users Percent Distribution (2014)')

plt.show()

# %%
# Create a histogram for the internet users percent in 2000 and 2014

sns.histplot(internet_2000_and_2014[internet_2000_and_2014['Year'] == 2000]['Internet_Users_Pct'], bins=20, kde=True)
plt.title('Internet Users Percent Distribution (2000)')

sns.histplot(internet_2000_and_2014[internet_2000_and_2014['Year'] == 2014]['Internet_Users_Pct'], bins=20, kde=True)
plt.title('Internet Users Percent Distribution (2014)')
plt.show()
